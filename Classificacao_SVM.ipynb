# %% [markdown]
# <a href="https://colab.research.google.com/github/eltondeoliveirasilva/Classificacao/blob/main/Classificacao_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn import datasets

# %%
bc = datasets.load_breast_cancer()
x = bc.data
y = bc.target

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1, stratify=y)

# %%
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train);

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(x_train)
x_train_std = sc.transform(x_train)
x_test_std = sc.transform(x_test)

# %%
svc = SVC(kernel='linear', C=1.0, random_state=1)
svc.fit(x_train_std, y_train)
# Out:
# SVC(kernel='linear', random_state=1)

# %%
from sklearn.metrics import accuracy_score

# %%
y_predict = svc.predict(x_test_std)

# %%
print('Acurácia %.3f'% accuracy_score(y_test, y_predict))
# Out:
# Acurácia 0.953
